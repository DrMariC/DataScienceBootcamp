# %%
# Import pandas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create a DataFrame with balance.txt
filename = "balance.txt"
df = pd.read_csv(filename, sep=' ')
df
# Out:
#        Balance   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0    12.240798   14.891   3606     283      2   34         11    Male      No
# 1    23.283334  106.025   6645     483      3   82         15  Female     Yes
# 2    22.530409  104.593   7075     514      4   71         11    Male      No
# 3    27.652811  148.924   9504     681      3   36         11  Female      No
# 4    16.893978   55.882   4897     357      2   68         16    Male      No
# ..         ...      ...    ...     ...    ...  ...        ...     ...     ...
# 395   8.764984   12.096   4100     307      3   32         13    Male      No
# 396   9.943838   13.364   3838     296      5   65         17    Male      No
# 397  14.882078   57.872   4171     321      5   67         12  Female      No
# 398  12.001071   37.728   2525     192      1   44         13    Male      No
# 399  10.159598   18.701   5524     415      5   64          7  Female      No
#
#     Married         Ethnicity
# ...

# %%
# Comparing the average income based on ethnicity indicates that African Americans earn the most.
df.Ethnicity.describe()
df.Ethnicity
print("The average income of Caucasian's is", df[df.Ethnicity == "Caucasian"].loc[:,"Income"].mean())
print("The average income of Asian's is", df[df.Ethnicity == "Asian"].loc[:,"Income"].mean())
print("The average income of African American's is", df[df.Ethnicity == "African American"].loc[:,"Income"].mean())
# Use data viz to understand the data better
plt.title('Bar Graph of Income by Ethnicity')
# Create a list of colors
colors = ['b', 'g', 'r', 'c', 'm']
sns.barplot(data = df, x='Ethnicity', y ='Income', palette = colors)
# Out:
# The average income of Caucasian's is 44.521944723618084
# The average income of Asian's is 44.18783333333334
# The average income of African American's is 47.68210101010099
# C:\Users\chikv\AppData\Local\Temp\ipykernel_16924\2652204040.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = df, x='Ethnicity', y ='Income', palette = colors)
# C:\Users\chikv\AppData\Local\Temp\ipykernel_16924\2652204040.py:11: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(data = df, x='Ethnicity', y ='Income', palette = colors)
# <Axes: title={'center': 'Bar Graph of Income by Ethnicity'}, xlabel='Ethnicity', ylabel='Income'>

# %%
# UPDATE FOR RESUBMISION:
# Instead of looking at the peaks of the datasets, this time I looked at the distribution (Thanks to the reviewer for the hint! ;)
# According to the KDE graps below, one can see how most of the data is distributed around a higher balance on average, for unmerried, vs merried.
# Unmeried distribution is also narrower than that of the married, indicating less spread. 
# According to the violin plot as well as the mean data you printed, on average, unmarried people actually have a slightly higher balance.

# Make a Kernel Density Plots (KDEs)
plt.title('Distribution Graph of Balance by Merital Status')
sns.kdeplot(data = df, x='Balance', hue='Married')
# Out:
# <Axes: title={'center': 'Distribution Graph of Balance by Merital Status'}, xlabel='Balance', ylabel='Density'>

# %%
# UPDATE FOR RESUBMISION: On average, unmarried people have a slightly higher balance than single people;
# This is clear when comparing the mean values printed (13.493509 > 13.388473),
# as well as the median (another measure of the average) on the violine graph (white line inside a box).
# This could be explained by the fact that having a family reqires more resources, such as bigger housing, more food, etc.
# Therefore there is more money spend and less left on balance.
print(df.groupby(['Married']).mean(numeric_only=True))
# Use data viz to understand the data better
plt.title('Violin Graph of Balance by Merital Status')
# Create a list of colors
colors = ['b', 'g', 'r', 'c', 'm']
sns.violinplot(data = df, x='Married', y ='Balance', palette = colors)
# Out:
#            Balance     Income        Limit      Rating     Cards        Age  \
# Married
# No       13.493509  43.641090  4645.303226  347.800000  2.974194  57.251613
# Yes      13.388473  46.217082  4792.726531  359.457143  2.946939  54.665306
#
#          Education
# Married
# No       13.258065
# Yes      13.571429
# C:\Users\chikv\AppData\Local\Temp\ipykernel_16924\262567573.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = df, x='Married', y ='Balance', palette = colors)
# C:\Users\chikv\AppData\Local\Temp\ipykernel_16924\262567573.py:11: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.violinplot(data = df, x='Married', y ='Balance', palette = colors)
# <Axes: title={'center': 'Violin Graph of Balance by Merital Status'}, xlabel='Married', ylabel='Balance'>

# %%
# According to the sumary statistis the highest income in the dataset is 186.634000
# sns.boxplot(data = df, x='Ethnicity', y ='Income', palette = colors)
sns.boxplot(data = df, x='Income')

df.describe()
# Out:
#           Balance      Income         Limit      Rating       Cards  \
# count  400.000000  400.000000    400.000000  400.000000  400.000000
# mean    13.429175   45.218885   4735.600000  354.940000    2.957500
# std      5.669256   35.244273   2308.198848  154.724143    1.371275
# min      3.749403   10.354000    855.000000   93.000000    1.000000
# 25%      9.891439   21.007250   3088.000000  247.250000    2.000000
# 50%     11.779615   33.115500   4622.500000  344.000000    3.000000
# 75%     15.236961   57.470750   5872.750000  437.250000    4.000000
# max     38.785123  186.634000  13913.000000  982.000000    9.000000
#
#               Age   Education
# count  400.000000  400.000000
# mean    55.667500   13.450000
# std     17.249807    3.125207
# min     23.000000    5.000000
# 25%     41.750000   11.000000
# 50%     56.000000   14.000000
# 75%     70.000000   16.000000
# max     98.000000   20.000000

# %%
# UPDATE FOR RESUBMISION: 
# This bit of code shows how many cards do we have recorded in our dataset.
sum_cards = df['Cards'].sum()
print("The total number of cards recorded in the dataset is: ", sum_cards)
# Out:
# The total number of cards recorded in the dataset is:  1183

# %%
# UPDATE FOR RESUBMISION: 
# This bit of code shows how many females do we have information for vs how many males.

gender_counts = df['Gender'].value_counts()
print("The total number of males and femails in the dataset is: \n", gender_counts)
# Out:
# The total number of males and femails in the dataset is:
#  Gender
# Female    207
# Male      193
# Name: count, dtype: int64

# %%
# The Pie Chart below shows in a vizual way that there are more femails than mails.

plt.figure(figsize=(4, 4))
plt.pie(gender_counts, labels=gender_counts.index)
# Add title
plt.title('Pie Chart by Gender')
# Out:
# Text(0.5, 1.0, 'Pie Chart by Gender')
